# %% [markdown]
# <a href="https://colab.research.google.com/github/Amodion/Face_detection/blob/main/Face_detection_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

import cv2

from ultralytics import YOLO

import clearml

# %matplotlib inline

# %%
#! pip install ultralytics
#! pip install clearml

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fareselmenshawii/face-detection-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 4.43G/4.43G [00:55<00:00, 86.4MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/fareselmenshawii/face-detection-dataset/versions/3

# %%
dataset_path = '/root/.cache/kagglehub/datasets/fareselmenshawii/face-detection-dataset/versions/3'

# %%
# !ls /root/.cache/kagglehub/datasets/fareselmenshawii/face-detection-dataset/versions/3
# Out:
# images	labels	labels2

# %%
im = cv2.cvtColor(cv2.imread(filename=dataset_path + '/images/train/00006c07d2b033d1.jpg'), cv2.COLOR_BGR2RGB)

# %%
plt.imshow(im)

# %%
clearml.browser_login()
# Out:
# ClearML automatic browser login failed, please login or create a new account
# To get started with ClearML: setup your own `clearml-server`, or create a free account at https://app.clear.ml
#
# Please login to https://app.clear.ml , then press [Enter] to connect
# We cannot connect automatically (adblocker / incognito?) 😟
# Please go to https://app.clear.ml/settings/workspace-configuration
# Then press  + Create new credentials
# And copy/paste your Access Key here: HVCWYUAUE3VSPSQ3J9D12FOYMBCZVT
#  Setting access key
# Now copy/paste your Secret Key here: 6-XYrZuKm-hrivjh00exQX6__kXh-9J4JhBYtlEa5NKlSPX46_kInDHfEC4F5fKxd_w
#  Setting secret key
#
#
# Hurrah! 🥳 🎊 🎉
# 🤖 ClearML connected successfully - let's build something! 🚀

# %%
model = YOLO('yolov5s.pt')
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 17.7M/17.7M [00:00<00:00, 126MB/s]

# %%
results = model.train(data='/content/data.yaml', project='Face detecton', name='first-run', resume=True)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:1 (Tesla T4, 15102MiB)
# ...

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-100f62972f2f> in <cell line: 1>()
# ----> 1 results
#
# NameError: name 'results' is not defined
